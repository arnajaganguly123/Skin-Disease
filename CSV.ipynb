# %% [markdown]
# <a href="https://colab.research.google.com/github/arnajaganguly123/Skin-Disease/blob/main/CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import matplotlib.pyplot as plt

# %%
a='scalp'
with open('/content/HAM10000_metadata.csv') as file:
    read=csv.reader(file)
    print('scalp')
    for row in read:
        if a in row:
          print(row[4:5])
# Out:
# scalp
# ['80.0']
# ['80.0']
# ['80.0']
# ['80.0']
# ['80.0']
# ['70.0']
# ['70.0']
# ['85.0']
# ['85.0']
# ['80.0']
# ['80.0']
# ['40.0']
# ['70.0']
# ['60.0']
# ['65.0']
# ['70.0']
# ['50.0']
# ['50.0']
# ['80.0']
# ['80.0']
# ['70.0']
# ['55.0']
# ['50.0']
# ['50.0']
# ['75.0']
# ['80.0']
# ['70.0']
# ['65.0']
# ['55.0']
# ['70.0']
# ['70.0']
# ['70.0']
# ['70.0']
# ['70.0']
# ['70.0']
# ['65.0']
# ['80.0']
# ['80.0']
# ['70.0']
# ['70.0']
# ['70.0']
# ['70.0']
# ['70.0']
# ['70.0']
# ['70.0']
# ['70.0']
# ['70.0']
# ['20.0']
# ['55.0']
# ['30.0']
# ['65.0']
# ['65.0']
# ['85.0']
# ['85.0']
# ['80.0']
# ['80.0']
# ['80.0']
# ['80.0']
# ['80.0']
# ['80.0']
# ['60.0']
# ['60.0']
# ['65.0']
# ['85.0']
# ['85.0']
# ['60.0']
# ['75.0']
# ['75.0']
# ['75.0']
# ['45.0']
# ['30.0']
# ['60.0']
# ['55.0']
# ['55.0']
# ['35.0']
# ['35.0']
# ['40.0']
# ['40.0']
# ['50.0']
# ['50.0']
# ['40.0']
# ['40.0']
# ['50.0']
# ['50.0']
# ['30.0']
# ['30.0']
# ['30.0']
# ['35.0']
# ['35.0']
# ['85.0']
# ...

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('HAM10000_metadata.csv')

# %%
df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
sns.boxplot(data=df,x='age',y='localization')

# %%
plt.plot(df['age'],df['localization']=='scalp')
